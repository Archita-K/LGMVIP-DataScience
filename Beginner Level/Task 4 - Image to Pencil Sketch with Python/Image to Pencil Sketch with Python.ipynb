# %% [markdown]
# # LetsGrowMoreVIP - Data Science Intern
# # Author - Archita K
# # Beginner Level Task 4 - Image to Pencil Sketch with Python
# We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.

# %% [markdown]
# # Import Modules

# %%
import cv2
import matplotlib.pyplot as plt
from cv2_plt_imshow import cv2_plt_imshow

# %% [markdown]
# # Read the image

# %%
org_image = cv2.imread('Doggy.jpg')

# %%
cv2.imshow("Dog",org_image)
plt.title('Original Image')
cv2_plt_imshow(org_image)

# %% [markdown]
# # Reading in RBG Format

# %%
rbg_image = cv2.cvtColor(org_image, cv2.COLOR_BGR2RGB)
plt.title('RBG Image')
cv2_plt_imshow(rbg_image)

# %% [markdown]
# # Converting the Image to Grayscale

# %%
grayscale_image = cv2.cvtColor(rbg_image, cv2.COLOR_BGR2GRAY)
plt.title('Grayscale Image')
cv2_plt_imshow(grayscale_image)

# %% [markdown]
# # Inverting the Grayscale Image

# %%
inverted_image = 255 - grayscale_image
plt.title('Inverted Grayscale Image')
cv2_plt_imshow(inverted_image)

# %% [markdown]
# # Blurring the Image using Gaussian Function

# %%
blurred_image = cv2.GaussianBlur(inverted_image,(21, 21), 0)
plt.title('Blurred Image')
cv2_plt_imshow(blurred_image)

# %% [markdown]
# # Inverting the Blurred Image

# %%
inverted_blurred = 255 - blurred_image
plt.title('Inverted Blurred Image')
cv2_plt_imshow(inverted_blurred)

# %% [markdown]
# # Final Sketch

# %%
pencil_sketch = cv2.divide(grayscale_image, inverted_blurred, scale=256.0)
plt.title('Pencil Sketch')
cv2_plt_imshow(pencil_sketch)

# %% [markdown]
# # Displaying Original Image and Pencil Sketch

# %%
cv2_plt_imshow(org_image)
plt.title('Original Image')
# Out:
# Text(0.5, 1.0, 'Original Image')

# %%
cv2_plt_imshow(pencil_sketch)
plt.title('Pencil Sketch')
# Out:
# Text(0.5, 1.0, 'Pencil Sketch')

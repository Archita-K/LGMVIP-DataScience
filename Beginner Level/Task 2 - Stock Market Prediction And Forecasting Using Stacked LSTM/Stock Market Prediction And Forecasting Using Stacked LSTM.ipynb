# %% [markdown]
# # LetsGrowMoreVIP - Data Science Intern
# # Author - Archita K
# # Beginner Level Task 2 - Stock Market Prediction And Forecasting Using Stacked LSTM

# %% [markdown]
# # Importing the Modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('NSE-TATAGLOBAL.csv')
data.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
data.describe()
# Out:
#               Open         High          Low         Last       Close  \
# count  2035.000000  2035.000000  2035.000000  2035.000000  2035.00000
# mean    149.713735   151.992826   147.293931   149.474251   149.45027
# std      48.664509    49.413109    47.931958    48.732570    48.71204
# min      81.100000    82.800000    80.000000    81.000000    80.95000
# 25%     120.025000   122.100000   118.300000   120.075000   120.05000
# 50%     141.500000   143.400000   139.600000   141.100000   141.25000
# 75%     157.175000   159.400000   155.150000   156.925000   156.90000
# max     327.700000   328.750000   321.650000   325.950000   325.75000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          2.035000e+03      2035.000000
# mean           2.335681e+06      3899.980565
# std            2.091778e+06      4570.767877
# min            3.961000e+04        37.040000
# 25%            1.146444e+06      1427.460000
# 50%            1.783456e+06      2512.030000
# 75%            2.813594e+06      4539.015000
# max            2.919102e+07     55755.080000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2035 entries, 0 to 2034
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2035 non-null   object
#  1   Open                  2035 non-null   float64
#  2   High                  2035 non-null   float64
#  3   Low                   2035 non-null   float64
#  4   Last                  2035 non-null   float64
#  5   Close                 2035 non-null   float64
#  6   Total Trade Quantity  2035 non-null   int64
#  7   Turnover (Lacs)       2035 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 127.3+ KB

# %%
data['Date'] = pd.to_datetime(data['Date'])
data.head()
# Out:
#         Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0 2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1 2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2 2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3 2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4 2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
data.dtypes
# Out:
# Date                    datetime64[ns]
# Open                           float64
# High                           float64
# Low                            float64
# Last                           float64
# Close                          float64
# Total Trade Quantity             int64
# Turnover (Lacs)                float64
# dtype: object

# %%
data['Date'].value_counts()
# Out:
# 2018-09-28    1
# 2013-04-10    1
# 2013-03-20    1
# 2013-03-21    1
# 2013-03-22    1
#              ..
# 2016-01-11    1
# 2016-01-12    1
# 2016-01-13    1
# 2016-01-14    1
# 2010-07-21    1
# Name: Date, Length: 2035, dtype: int64

# %%
data.shape
# Out:
# (2035, 8)

# %%
data.isnull().sum()
# Out:
# Date                    0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Close                   0
# Total Trade Quantity    0
# Turnover (Lacs)         0
# dtype: int64

# %%
df = data.sort_values('Date')
df.head()
# Out:
#            Date   Open    High     Low    Last   Close  Total Trade Quantity  \
# 2034 2010-07-21  122.1  123.00  121.05  121.10  121.55                658666
# 2033 2010-07-22  120.3  122.00  120.25  120.75  120.90                293312
# 2032 2010-07-23  121.8  121.95  120.25  120.35  120.65                281312
# 2031 2010-07-26  120.1  121.00  117.10  117.10  117.60                658440
# 2030 2010-07-27  117.6  119.50  112.00  118.80  118.65                586100
#
#       Turnover (Lacs)
# 2034           803.56
# 2033           355.17
# 2032           340.31
# 2031           780.01
# 2030           694.98

# %%
df.reset_index(inplace=True)

# %%
df_close = df['Close']
df_close
# Out:
# 0       121.55
# 1       120.90
# 2       120.65
# 3       117.60
# 4       118.65
#          ...
# 2030    233.30
# 2031    236.10
# 2032    234.25
# 2033    233.25
# 2034    233.75
# Name: Close, Length: 2035, dtype: float64

# %% [markdown]
# # Data Visualisation

# %%
plt.plot(df['Close'])

# %%
df['High'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,10))
plt.plot(df)
# Out:
# [<matplotlib.lines.Line2D at 0x1fc05d60fd0>,
#  <matplotlib.lines.Line2D at 0x1fc058d5bb0>,
#  <matplotlib.lines.Line2D at 0x1fc05d6a0a0>,
#  <matplotlib.lines.Line2D at 0x1fc05d6a160>,
#  <matplotlib.lines.Line2D at 0x1fc05d6a220>,
#  <matplotlib.lines.Line2D at 0x1fc05d6a2e0>,
#  <matplotlib.lines.Line2D at 0x1fc05d6a3a0>,
#  <matplotlib.lines.Line2D at 0x1fc05d6a460>,
#  <matplotlib.lines.Line2D at 0x1fc05d6a520>]

# %%
sns.pairplot(df)

# %% [markdown]
# # Applying MinMaxScalar

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scalar = MinMaxScaler()
df_close=scalar.fit_transform(np.array(df_close).reshape(-1,1))
df_close
# Out:
# array([[0.16584967],
#        [0.16319444],
#        [0.1621732 ],
#        ...,
#        [0.62622549],
#        [0.62214052],
#        [0.62418301]])

# %% [markdown]
# The scaling and transform is complete as you can see it above in an array

# %% [markdown]
# # Splitting the data

# %%
training_size = int(len(df_close)*0.70)
test_size = len(df_close) - training_size
train, test = df_close[0 : training_size, :], df_close[training_size : len(df_close), :1]

# %%
# Converting the previously calculated array values into a matrix
def create_matrix(ds, time_step=1):
    dataX, dataY = [], []
    for i in range(len(ds)-time_step-1):
        a = ds[i:(i+time_step),0]
        dataX.append(a)
        dataY.append(ds[i+time_step,0])
    return np.array(dataX), np.array(dataY)

# %%
time_step=100
X_train, y_train = create_matrix(train, time_step)
X_test, y_test = create_matrix(test, time_step)

# %%
X_train.shape
# Out:
# (1323, 100)

# %%
y_train.shape
# Out:
# (1323,)

# %%
X_test.shape
# Out:
# (510, 100)

# %%
y_test.shape
# Out:
# (510,)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# # Creating LSTM Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, validation_split=0.1, epochs=60, batch_size=64, verbose=1)
# Out:
# Epoch 1/60
# 19/19 [==============================] - 7s 161ms/step - loss: 0.0103 - val_loss: 0.0018
# Epoch 2/60
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 3/60
# 19/19 [==============================] - 2s 102ms/step - loss: 9.8795e-04 - val_loss: 0.0012
# Epoch 4/60
# 19/19 [==============================] - 2s 110ms/step - loss: 8.4565e-04 - val_loss: 0.0012
# Epoch 5/60
# 19/19 [==============================] - 2s 125ms/step - loss: 7.9642e-04 - val_loss: 0.0011
# Epoch 6/60
# 19/19 [==============================] - 2s 126ms/step - loss: 8.1608e-04 - val_loss: 0.0010
# Epoch 7/60
# 19/19 [==============================] - 2s 127ms/step - loss: 7.5258e-04 - val_loss: 9.8136e-04
# Epoch 8/60
# 19/19 [==============================] - 2s 124ms/step - loss: 7.4467e-04 - val_loss: 9.1787e-04
# Epoch 9/60
# 19/19 [==============================] - 2s 122ms/step - loss: 7.0392e-04 - val_loss: 8.9794e-04
# Epoch 10/60
# 19/19 [==============================] - 2s 126ms/step - loss: 6.9159e-04 - val_loss: 8.4942e-04
# Epoch 11/60
# 19/19 [==============================] - 3s 139ms/step - loss: 6.8622e-04 - val_loss: 8.0843e-04
# Epoch 12/60
# 19/19 [==============================] - 2s 128ms/step - loss: 6.5828e-04 - val_loss: 8.3186e-04
# Epoch 13/60
# 19/19 [==============================] - 2s 124ms/step - loss: 6.4647e-04 - val_loss: 8.3969e-04
# Epoch 14/60
# 19/19 [==============================] - 2s 125ms/step - loss: 6.4901e-04 - val_loss: 7.1267e-04
# Epoch 15/60
# 19/19 [==============================] - 2s 125ms/step - loss: 5.9782e-04 - val_loss: 7.2776e-04
# Epoch 16/60
# 19/19 [==============================] - 2s 127ms/step - loss: 5.9667e-04 - val_loss: 6.7525e-04
# Epoch 17/60
# 19/19 [==============================] - 3s 148ms/step - loss: 5.7045e-04 - val_loss: 6.5700e-04
# Epoch 18/60
# 19/19 [==============================] - 2s 129ms/step - loss: 6.2702e-04 - val_loss: 8.6748e-04
# Epoch 19/60
# 19/19 [==============================] - 3s 170ms/step - loss: 5.9395e-04 - val_loss: 8.0550e-04
# Epoch 20/60
# 19/19 [==============================] - 3s 145ms/step - loss: 5.4046e-04 - val_loss: 6.8515e-04
# Epoch 21/60
# 19/19 [==============================] - 3s 131ms/step - loss: 5.3366e-04 - val_loss: 5.6355e-04
# Epoch 22/60
# 19/19 [==============================] - 2s 126ms/step - loss: 5.4053e-04 - val_loss: 6.3058e-04
# Epoch 23/60
# 19/19 [==============================] - 2s 131ms/step - loss: 5.4042e-04 - val_loss: 5.6134e-04
# Epoch 24/60
# 19/19 [==============================] - 3s 139ms/step - loss: 5.0596e-04 - val_loss: 5.4593e-04
# Epoch 25/60
# 19/19 [==============================] - 3s 144ms/step - loss: 4.8393e-04 - val_loss: 4.9716e-04
# Epoch 26/60
# 19/19 [==============================] - 3s 146ms/step - loss: 5.1462e-04 - val_loss: 6.2910e-04
# Epoch 27/60
# 19/19 [==============================] - 3s 135ms/step - loss: 5.3737e-04 - val_loss: 5.2578e-04
# Epoch 28/60
# 19/19 [==============================] - 2s 131ms/step - loss: 4.7328e-04 - val_loss: 6.2441e-04
# Epoch 29/60
# 19/19 [==============================] - 2s 129ms/step - loss: 4.7202e-04 - val_loss: 4.6658e-04
# Epoch 30/60
# 19/19 [==============================] - 3s 142ms/step - loss: 4.2996e-04 - val_loss: 4.5973e-04
# Epoch 31/60
# 19/19 [==============================] - 2s 127ms/step - loss: 4.2647e-04 - val_loss: 4.8586e-04
# Epoch 32/60
# 19/19 [==============================] - 2s 125ms/step - loss: 4.2200e-04 - val_loss: 4.1038e-04
# Epoch 33/60
# 19/19 [==============================] - 2s 128ms/step - loss: 4.3215e-04 - val_loss: 4.0254e-04
# Epoch 34/60
# 19/19 [==============================] - 2s 125ms/step - loss: 4.1229e-04 - val_loss: 3.9872e-04
# Epoch 35/60
# 19/19 [==============================] - 3s 139ms/step - loss: 3.9414e-04 - val_loss: 4.1430e-04
# Epoch 36/60
# 19/19 [==============================] - 3s 145ms/step - loss: 3.8509e-04 - val_loss: 3.8970e-04
# Epoch 37/60
# 19/19 [==============================] - 3s 138ms/step - loss: 3.7962e-04 - val_loss: 3.7401e-04
# Epoch 38/60
# 19/19 [==============================] - 3s 139ms/step - loss: 3.8414e-04 - val_loss: 3.8182e-04
# Epoch 39/60
# 19/19 [==============================] - 3s 138ms/step - loss: 3.6132e-04 - val_loss: 3.6872e-04
# Epoch 40/60
# 19/19 [==============================] - 3s 144ms/step - loss: 3.5390e-04 - val_loss: 3.7874e-04
# Epoch 41/60
# 19/19 [==============================] - 3s 164ms/step - loss: 3.3973e-04 - val_loss: 3.1532e-04
# Epoch 42/60
# 19/19 [==============================] - 3s 151ms/step - loss: 3.3235e-04 - val_loss: 3.1620e-04
# Epoch 43/60
# 19/19 [==============================] - 3s 153ms/step - loss: 3.5784e-04 - val_loss: 2.9959e-04
# Epoch 44/60
# 19/19 [==============================] - 3s 153ms/step - loss: 3.1020e-04 - val_loss: 2.8367e-04
# Epoch 45/60
# 19/19 [==============================] - 3s 147ms/step - loss: 2.9629e-04 - val_loss: 2.6232e-04
# Epoch 46/60
# 19/19 [==============================] - 3s 143ms/step - loss: 3.2243e-04 - val_loss: 2.9479e-04
# Epoch 47/60
# 19/19 [==============================] - 3s 139ms/step - loss: 3.1656e-04 - val_loss: 2.8074e-04
# Epoch 48/60
# 19/19 [==============================] - 3s 145ms/step - loss: 2.9535e-04 - val_loss: 2.4322e-04
# Epoch 49/60
# 19/19 [==============================] - 3s 144ms/step - loss: 2.7290e-04 - val_loss: 2.4068e-04
# Epoch 50/60
# 19/19 [==============================] - 3s 139ms/step - loss: 2.6868e-04 - val_loss: 2.4166e-04
# Epoch 51/60
# 19/19 [==============================] - 3s 141ms/step - loss: 2.6233e-04 - val_loss: 2.5349e-04
# Epoch 52/60
# 19/19 [==============================] - 3s 152ms/step - loss: 2.6199e-04 - val_loss: 2.1038e-04
# Epoch 53/60
# 19/19 [==============================] - 3s 179ms/step - loss: 2.5325e-04 - val_loss: 2.1192e-04
# Epoch 54/60
# 19/19 [==============================] - 3s 177ms/step - loss: 2.4083e-04 - val_loss: 2.1200e-04
# Epoch 55/60
# 19/19 [==============================] - 3s 138ms/step - loss: 2.3616e-04 - val_loss: 2.0237e-04
# Epoch 56/60
# 19/19 [==============================] - 3s 162ms/step - loss: 2.2864e-04 - val_loss: 1.9378e-04
# Epoch 57/60
# 19/19 [==============================] - 3s 155ms/step - loss: 2.1411e-04 - val_loss: 2.1164e-04
# Epoch 58/60
# 19/19 [==============================] - 3s 140ms/step - loss: 2.3091e-04 - val_loss: 1.8255e-04
# Epoch 59/60
# 19/19 [==============================] - 3s 137ms/step - loss: 2.1666e-04 - val_loss: 1.8306e-04
# Epoch 60/60
# 19/19 [==============================] - 3s 136ms/step - loss: 2.0611e-04 - val_loss: 1.7457e-04

# %% [markdown]
# # Predictions

# %%
predictions = model.predict(X_test)

# %% [markdown]
# ### Inverse Transform on Predictions

# %%
inverse_predictions = scalar.inverse_transform(predictions)

# %%
inverse_predictions()
# Out:
# array([[142.15529 ],
#        [142.36922 ],
#        [141.52513 ],
#        [138.95316 ],
#        [137.24785 ],
#        [136.58208 ],
#        [137.6111  ],
#        [139.14546 ],
#        [139.66827 ],
#        [139.45804 ],
#        [139.27264 ],
#        [140.36058 ],
#        [141.09425 ],
#        [142.5921  ],
#        [144.7186  ],
#        [142.90973 ],
#        [140.57983 ],
#        [140.04828 ],
#        [140.48636 ],
#        [145.19449 ],
#        [149.58089 ],
#        [151.98665 ],
#        [152.57364 ],
#        [150.64319 ],
#        [150.22478 ],
#        [149.75824 ],
#        [149.98901 ],
#        [151.56822 ],
#        [152.38066 ],
#        [152.52715 ],
#        [152.97015 ],
#        [151.9009  ],
#        [148.78891 ],
#        [143.25809 ],
#        [139.74364 ],
#        [138.5667  ],
#        [138.64806 ],
#        [138.0007  ],
#        [135.96861 ],
#        [132.5314  ],
#        [130.00743 ],
#        [128.65627 ],
#        [126.5268  ],
#        [125.606316],
#        [123.623764],
#        [121.09466 ],
#        [120.28322 ],
#        [119.8829  ],
#        [120.05796 ],
#        [119.211205],
#        [118.39855 ],
#        [117.97876 ],
#        [117.189705],
#        [117.247375],
#        [118.44097 ],
#        [120.15217 ],
#        [122.09637 ],
#        [123.0357  ],
#        [122.990845],
#        [123.0565  ],
#        [123.1853  ],
#        [123.00559 ],
#        [123.15008 ],
#        [123.50762 ],
#        [123.73152 ],
#        [123.827065],
#        [123.69391 ],
#        [123.98412 ],
#        [124.42577 ],
#        [124.800385],
#        [124.160095],
#        [123.25312 ],
#        [121.9464  ],
#        [120.68073 ],
#        [119.34696 ],
#        [119.318   ],
#        [119.79453 ],
#        [120.71986 ],
#        [121.83881 ],
#        [123.125404],
#        [124.35232 ],
#        [125.14557 ],
#        [125.64277 ],
#        [125.67883 ],
#        [125.47841 ],
#        [125.15294 ],
#        [125.768745],
#        [126.067894],
#        [126.9638  ],
#        [127.77119 ],
#        [128.23332 ],
#        [128.68854 ],
#        [129.58612 ],
#        [129.23111 ],
#        [128.70764 ],
#        [128.52861 ],
#        [128.58797 ],
#        [128.99814 ],
#        [129.84387 ],
#        [130.16388 ],
#        [130.43903 ],
#        [132.95834 ],
#        [137.26866 ],
#        [141.28047 ],
#        [143.21451 ],
#        [144.81625 ],
#        [144.98592 ],
#        [144.30812 ],
#        [142.82526 ],
#        [141.30151 ],
#        [139.6062  ],
#        [139.01039 ],
#        [139.33444 ],
#        [140.53531 ],
#        [141.77174 ],
#        [142.00395 ],
#        [141.36508 ],
#        [140.42334 ],
#        [139.39203 ],
#        [140.55495 ],
#        [141.57034 ],
#        [142.74203 ],
#        [143.52737 ],
#        [143.60439 ],
#        [142.80482 ],
#        [141.65996 ],
#        [139.53456 ],
#        [138.54485 ],
#        [139.06721 ],
#        [141.44737 ],
#        [143.91359 ],
#        [145.98732 ],
#        [146.8633  ],
#        [145.7598  ],
#        [147.1043  ],
#        [149.12607 ],
#        [149.58601 ],
#        [149.73734 ],
#        [149.79843 ],
#        [149.6501  ],
#        [149.63712 ],
#        [150.25656 ],
#        [151.2679  ],
#        [152.22781 ],
#        [151.85933 ],
#        [151.1324  ],
#        [151.53467 ],
#        [151.73381 ],
#        [151.22101 ],
#        [150.20062 ],
#        [148.91234 ],
#        [148.82005 ],
#        [150.11862 ],
#        [151.21527 ],
#        [151.93697 ],
#        [152.0807  ],
#        [152.63322 ],
#        [152.51959 ],
#        [152.43193 ],
#        [154.16649 ],
#        [155.49796 ],
#        [155.62712 ],
#        [153.94852 ],
#        [152.2702  ],
#        [151.96103 ],
#        [152.78891 ],
#        [153.48401 ],
#        [153.29947 ],
#        [153.55424 ],
#        [153.9149  ],
#        [153.5185  ],
#        [150.84634 ],
#        [148.97443 ],
#        [147.74905 ],
#        [146.17105 ],
#        [143.94504 ],
#        [142.8351  ],
#        [144.15245 ],
#        [145.5809  ],
#        [146.40863 ],
#        [147.96173 ],
#        [150.34682 ],
#        [152.99208 ],
#        [154.59727 ],
#        [154.15617 ],
#        [153.8093  ],
#        [153.35144 ],
#        [152.93413 ],
#        [151.88646 ],
#        [152.71967 ],
#        [155.05121 ],
#        [157.39383 ],
#        [158.38675 ],
#        [157.60452 ],
#        [156.5248  ],
#        [155.81279 ],
#        [154.78613 ],
#        [152.65286 ],
#        [149.51042 ],
#        [148.01707 ],
#        [147.80736 ],
#        [149.08171 ],
#        [150.90744 ],
#        [151.60332 ],
#        [153.6827  ],
#        [154.5139  ],
#        [155.86086 ],
#        [160.30997 ],
#        [165.4912  ],
#        [170.2388  ],
#        [173.1733  ],
#        [173.22224 ],
#        [173.00371 ],
#        [171.4132  ],
#        [170.59972 ],
#        [169.0926  ],
#        [168.60155 ],
#        [168.17603 ],
#        [168.69946 ],
#        [170.07137 ],
#        [169.61044 ],
#        [168.86502 ],
#        [168.57999 ],
#        [167.7019  ],
#        [165.85744 ],
#        [165.08589 ],
#        [165.09155 ],
#        [167.08221 ],
#        [167.11629 ],
#        [164.44221 ],
#        [159.26357 ],
#        [158.80595 ],
#        [166.9414  ],
#        [181.80771 ],
#        [191.04607 ],
#        [194.18427 ],
#        [193.45665 ],
#        [188.03105 ],
#        [186.26001 ],
#        [186.07646 ],
#        [186.39246 ],
#        [185.8281  ],
#        [188.9136  ],
#        [192.78549 ],
#        [194.81491 ],
#        [192.94499 ],
#        [192.10463 ],
#        [196.64671 ],
#        [200.66975 ],
#        [202.52333 ],
#        [203.47969 ],
#        [204.76309 ],
#        [202.91246 ],
#        [203.1684  ],
#        [203.50085 ],
#        [205.12468 ],
#        [207.95775 ],
#        [208.43008 ],
#        [206.96936 ],
#        [200.06738 ],
#        [192.932   ],
#        [194.29077 ],
#        [195.47174 ],
#        [198.2829  ],
#        [201.63853 ],
#        [203.43219 ],
#        [202.48494 ],
#        [202.86343 ],
#        [203.31224 ],
#        [202.56636 ],
#        [201.73921 ],
#        [201.86194 ],
#        [203.67014 ],
#        [204.29173 ],
#        [203.8174  ],
#        [203.64767 ],
#        [201.98766 ],
#        [199.65048 ],
#        [197.79704 ],
#        [200.66283 ],
#        [201.6448  ],
#        [203.51509 ],
#        [210.02919 ],
#        [217.45618 ],
#        [220.4451  ],
#        [219.90399 ],
#        [217.24182 ],
#        [214.64368 ],
#        [218.62538 ],
#        [217.8627  ],
#        [215.85112 ],
#        [223.44463 ],
#        [227.80133 ],
#        [227.26857 ],
#        [231.72003 ],
#        [237.11334 ],
#        [239.60452 ],
#        [243.41602 ],
#        [252.7448  ],
#        [256.6915  ],
#        [256.65555 ],
#        [255.83673 ],
#        [257.52057 ],
#        [258.5634  ],
#        [264.56677 ],
#        [264.50967 ],
#        [266.6298  ],
#        [266.3167  ],
#        [263.27838 ],
#        [262.17194 ],
#        [259.8959  ],
#        [263.7851  ],
#        [269.15842 ],
#        [276.2489  ],
#        [273.37897 ],
#        [267.70117 ],
#        [264.8344  ],
#        [266.04684 ],
#        [269.85138 ],
#        [276.9808  ],
#        [280.22586 ],
#        [279.75714 ],
#        [279.7898  ],
#        [281.44745 ],
#        [282.24887 ],
#        [283.02054 ],
#        [288.41284 ],
#        [289.65652 ],
#        [288.35004 ],
#        [287.488   ],
#        [287.97748 ],
#        [288.97775 ],
#        [291.90726 ],
#        [292.2183  ],
#        [291.15128 ],
#        [290.09293 ],
#        [295.96536 ],
#        [298.0157  ],
#        [294.5935  ],
#        [290.86603 ],
#        [285.5204  ],
#        [285.07202 ],
#        [286.44534 ],
#        [286.50946 ],
#        [284.64203 ],
#        [283.38165 ],
#        [281.62537 ],
#        [281.87613 ],
#        [275.41724 ],
#        [270.42865 ],
#        [262.02774 ],
#        [257.60352 ],
#        [253.94977 ],
#        [260.23413 ],
#        [264.86713 ],
#        [264.28784 ],
#        [265.63254 ],
#        [264.31033 ],
#        [261.17896 ],
#        [257.69968 ],
#        [252.49509 ],
#        [247.88545 ],
#        [249.02377 ],
#        [249.0372  ],
#        [253.43079 ],
#        [257.53372 ],
#        [259.21628 ],
#        [258.9006  ],
#        [257.46918 ],
#        [256.85757 ],
#        [256.09738 ],
#        [253.19879 ],
#        [254.3076  ],
#        [253.45177 ],
#        [256.88657 ],
#        [260.4899  ],
#        [261.79245 ],
#        [261.99374 ],
#        [257.79922 ],
#        [248.78618 ],
#        [245.38078 ],
#        [246.94275 ],
#        [246.96616 ],
#        [246.25755 ],
#        [248.10349 ],
#        [250.08923 ],
#        [247.76338 ],
#        [254.897   ],
#        [258.61618 ],
#        [256.0876  ],
#        [254.64534 ],
#        [254.2462  ],
#        [257.2009  ],
#        [258.1981  ],
#        [257.32837 ],
#        [256.71054 ],
#        [257.59866 ],
#        [260.6223  ],
#        [262.9654  ],
#        [265.16025 ],
#        [266.8433  ],
#        [267.19528 ],
#        [265.48956 ],
#        [264.1801  ],
#        [267.12067 ],
#        [270.4843  ],
#        [272.27423 ],
#        [275.2764  ],
#        [274.06326 ],
#        [269.3742  ],
#        [267.6276  ],
#        [271.3578  ],
#        [271.8487  ],
#        [272.4854  ],
#        [269.23257 ],
#        [268.2669  ],
#        [251.7059  ],
#        [234.70538 ],
#        [228.79231 ],
#        [234.43912 ],
#        [238.67711 ],
#        [238.93338 ],
#        [239.06406 ],
#        [239.67888 ],
#        [241.27922 ],
#        [243.07327 ],
#        [244.61382 ],
#        [243.03496 ],
#        [245.04498 ],
#        [249.37482 ],
#        [248.5582  ],
#        [242.65854 ],
#        [243.9483  ],
#        [248.03122 ],
#        [251.2399  ],
#        [252.1842  ],
#        [250.12381 ],
#        [250.52737 ],
#        [252.44798 ],
#        [257.8369  ],
#        [257.7178  ],
#        [257.68066 ],
#        [253.31744 ],
#        [247.3185  ],
#        [243.70346 ],
#        [245.73894 ],
#        [249.7503  ],
#        [253.30464 ],
#        [253.29054 ],
#        [250.99362 ],
#        [252.02501 ],
#        [250.51816 ],
#        [257.8181  ],
#        [260.85413 ],
#        [257.33118 ],
#        [251.60062 ],
#        [253.87329 ],
#        [256.89935 ],
#        [255.73317 ],
#        [251.89758 ],
#        [246.58232 ],
#        [236.00867 ],
#        [233.75023 ],
#        [230.97444 ],
#        [227.12773 ],
#        [228.67804 ],
#        [233.37587 ],
#        [237.18109 ],
#        [232.65047 ],
#        [228.75952 ],
#        [228.7885  ],
#        [229.7583  ],
#        [232.81161 ],
#        [228.66237 ],
#        [224.64027 ],
#        [223.01141 ],
#        [225.99251 ],
#        [227.83429 ],
#        [227.52585 ],
#        [227.18376 ],
#        [224.95961 ],
#        [223.92015 ],
#        [225.54251 ],
#        [227.99565 ],
#        [231.05502 ],
#        [233.40492 ],
#        [231.41682 ],
#        [226.35548 ],
#        [221.12032 ],
#        [222.63335 ],
#        [223.90448 ],
#        [225.1783  ],
#        [226.62253 ],
#        [226.27025 ],
#        [226.61249 ],
#        [219.93987 ],
#        [214.19946 ],
#        [211.88945 ],
#        [213.46773 ],
#        [215.20312 ],
#        [212.88457 ],
#        [213.97379 ],
#        [221.36201 ],
#        [227.42796 ],
#        [227.92531 ],
#        [225.55363 ],
#        [223.09312 ],
#        [221.28658 ],
#        [222.45503 ],
#        [223.30797 ]], dtype=float32)

# %% [markdown]
# # Evaluation

# %%
import math
from sklearn.metrics import mean_squared_error

# %%
mse = math.sqrt(mean_squared_error(y_test, predictions))
print("The Mean Squared Error is:",mse)
# Out:
# The Mean Squared Error is: 0.049080601430126616

# %% [markdown]
# # Visualizing the Final Prediction

# %%
plt.figure(figsize=(10,10))
plt.plot(y_test, label="True Value")
plt.plot(predictions, label="LSTM Value")
plt.title("Stock Market Prediction and Forecasting using LSTM")
plt.xlabel("Time Scale")
plt.ylabel("Scaled Rupees")
plt.legend()
plt.show()
